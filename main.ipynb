# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/Quera-fr/Python-Programming/refs/heads/main/data.csv')
df = df.drop(['ID', 'Var_1'], axis=1).dropna()

y = df.Ever_Married.replace('Yes',1).replace('No',0)
X = df.drop(['Ever_Married'], axis=1)
X
# Out:
# C:\Users\mathi\AppData\Local\Temp\ipykernel_8576\4057965049.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   y = df.Ever_Married.replace('Yes',1).replace('No',0)
#       Gender  Age Graduated  Profession  Work_Experience Spending_Score  \
# 0       Male   22        No  Healthcare              1.0            Low
# 2     Female   67       Yes    Engineer              1.0            Low
# 3       Male   67       Yes      Lawyer              0.0           High
# 5       Male   56        No      Artist              0.0        Average
# 6       Male   32       Yes  Healthcare              1.0            Low
# ...      ...  ...       ...         ...              ...            ...
# 8062    Male   41       Yes      Artist              0.0           High
# 8064    Male   35        No   Executive              3.0            Low
# 8065  Female   33       Yes  Healthcare              1.0            Low
# 8066  Female   27       Yes  Healthcare              1.0            Low
# 8067    Male   37       Yes   Executive              0.0        Average
#
#       Family_Size Segmentation
# 0             4.0            D
# 2             1.0            B
# 3             2.0            B
# 5             2.0            C
# 6             3.0            C
# ...           ...          ...
# 8062          5.0            B
# 8064          4.0            D
# 8065          1.0            D
# 8066          4.0            B
# 8067          3.0            B
#
# [6718 rows x 8 columns]

# %%
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer

preprocessor = ColumnTransformer(
    transformers=[
        ('oneHot_encoding', OneHotEncoder(), X.select_dtypes('object').columns),
        ('standard', StandardScaler(), X.select_dtypes(include='number').columns),
        ])

pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('Model', RandomForestClassifier())]
)
pipeline
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('oneHot_encoding',
#                                                   OneHotEncoder(),
#                                                   Index(['Gender', 'Graduated', 'Profession', 'Spending_Score', 'Segmentation'], dtype='object')),
#                                                  ('standard', StandardScaler(),
#                                                   Index(['Age', 'Work_Experience', 'Family_Size'], dtype='object'))])),
#                 ('Model', RandomForestClassifier())])

# %%
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer

preprocessor = ColumnTransformer(
    transformers=[
        ('oneHot_encoding', OneHotEncoder(), X.select_dtypes('object').columns),
        ('standard', StandardScaler(), X.select_dtypes(include='number').columns),
        ])

pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('Model', RandomForestClassifier())]
)
pipeline
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('oneHot_encoding',
#                                                   OneHotEncoder(),
#                                                   Index(['Gender', 'Graduated', 'Profession', 'Spending_Score', 'Segmentation'], dtype='object')),
#                                                  ('standard', StandardScaler(),
#                                                   Index(['Age', 'Work_Experience', 'Family_Size'], dtype='object'))])),
#                 ('Model', RandomForestClassifier())])

# %%
pipeline.fit(X, y)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('oneHot_encoding',
#                                                   OneHotEncoder(),
#                                                   Index(['Gender', 'Graduated', 'Profession', 'Spending_Score', 'Segmentation'], dtype='object')),
#                                                  ('standard', StandardScaler(),
#                                                   Index(['Age', 'Work_Experience', 'Family_Size'], dtype='object'))])),
#                 ('Model', RandomForestClassifier())])

# %%
pipeline.score(X, y)
# Out:
# 0.9903245013396844

# %%
X.iloc[:1]
# Out:
#   Gender  Age Graduated  Profession  Work_Experience Spending_Score  \
# 0   Male   22        No  Healthcare              1.0            Low
#
#    Family_Size Segmentation
# 0          4.0            D

# %%
pipeline.predict(X.iloc[:1])[0]
# Out:
# np.int64(0)

# %%
import pickle

with open('model.pkl', 'wb') as file:
    pickle.dump(pipeline, file)

# %%
with open('model.pkl', 'rb') as file:
    model = pickle.load(file)

# %%
model
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('oneHot_encoding',
#                                                   OneHotEncoder(),
#                                                   Index(['Gender', 'Graduated', 'Profession', 'Spending_Score', 'Segmentation'], dtype='object')),
#                                                  ('standard', StandardScaler(),
#                                                   Index(['Age', 'Work_Experience', 'Family_Size'], dtype='object'))])),
#                 ('Model', RandomForestClassifier())])
